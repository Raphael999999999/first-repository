# %% [markdown]
# <a href="https://colab.research.google.com/github/Raphael999999999/first-repository/blob/main/some%20songs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data={'Song':['We dont talk about pluto','Celebration','Santa claus is coming to town','In the hall of the mountain king','Time is now','Lovely day','Lava chicken','Thriller' ],'Artist':['Jon pumper','Otis mcdonald','Michael Jackson','Edvard Greig','Sizzlebird', 'Bill Withers','Jack Black','Michael Jackson'], 'Energy levels':[0.1,0.9,0.7,0.8,0.5,0.8,0.7,0.5],'Day played':['Tuesday','Saturday','Sunday','Tuesday','Tuesday','Monday','Saturday','Saturday']}
data=pd.DataFrame(data)
print(data)
def head (n: int=5) -> pd.DataFrame:
  return data.head(n)

print(head())
# Out:
#                                Song           Artist  Energy levels Day played
# 0          We dont talk about pluto       Jon pumper            0.1    Tuesday
# 1                       Celebration    Otis mcdonald            0.9   Saturday
# 2     Santa claus is coming to town  Michael Jackson            0.7     Sunday
# 3  In the hall of the mountain king     Edvard Greig            0.8    Tuesday
# 4                       Time is now       Sizzlebird            0.5    Tuesday
# 5                        Lovely day     Bill Withers            0.8     Monday
# 6                      Lava chicken       Jack Black            0.7   Saturday
# 7                          Thriller  Michael Jackson            0.5   Saturday
#                                Song           Artist  Energy levels Day played
# 0          We dont talk about pluto       Jon pumper            0.1    Tuesday
# 1                       Celebration    Otis mcdonald            0.9   Saturday
# ...

# %%
# ai generated code

artist_counts = data['Artist'].value_counts()
most_frequent_artist = artist_counts.index[0]
print("favourite 'artist':")
most_frequent_artist
# Out:
# favourite 'artist':
# 'Michael Jackson'

# %%
average=((0.1+0.9+0.7+0.8+0.5+0.8+0.7+0.5)/8)
print('average energy level is',average)

if average<0.4:
  print('Im just a chill guy')
if average>0.6:
  print('I cant calm down')
else:
  print('Im in between, not energetic or chill')
# Out:
# average energy level is 0.625
# I cant calm down

# %%
import matplotlib.pyplot as plt
import numpy as np
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
songs = [1, 3, 0, 0, 0, 3, 1]

plt.bar(days, songs)
plt.title('Days and how many songs I listen to on those days')
plt.xlabel('days')
plt.ylabel('Songs')
plt.show()
print('I think that I listen to music mostly on tuesday and saturday because of this project')
# Out:
# I think that I listen to music mostly on tuesday and saturday because of this project

# %%
x = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
y = [1, 3, 0, 0, 0, 3, 1]

plt.plot(x, y, label="no.of songs", color="red", linewidth=2)

plt.title("Days and how many songs I listen to on those days")
plt.xlabel("days")
plt.ylabel("No.of songs")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()

plt.show()

print('I think this is meaningful because it shows the frequency of songs listened to over a period of time')
# Out:
# I think this is meaningful because it shows the frequency of songs listened to over a period of time
